# %% [markdown]
# # GrievX SVM Regression Project

# %%
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.pipeline import Pipeline

from sklearn.svm import SVR

from sklearn.metrics import mean_absolute_error

import joblib

# %%
df = pd.read_csv(
    "expanded_historical_complaints_dataset.csv"
)

df.head()
# Out:
#                Problem_Name Problem_Category  \
# 0  Government housing delay          housing
# 1  Government housing delay          housing
# 2  Government housing delay          housing
# 3  Government housing delay          housing
# 4  Government housing delay          housing
#
#                                      Ministry Minister_Name  Days_To_Complete
# 0  minister for housing and urban development   S Muthusamy                 4
# 1  minister for housing and urban development   S Muthusamy                10
# 2  minister for housing and urban development   S Muthusamy                 6
# 3  minister for housing and urban development   S Muthusamy                 4
# 4  minister for housing and urban development   S Muthusamy                 4

# %%
X = df["Problem_Name"]

y = df["Days_To_Complete"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=0
)

# %%
model = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('regressor', SVR())
])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('regressor', SVR())])

# %%
y_pred = model.predict(X_test)

print(y_pred)
# Out:
# [18.89999213 19.09995182 20.09986167 ... 20.89992632 14.69395803
#  17.90008055]

# %%
score = model.score(X_test, y_test)

print("Score :", score)
# Out:
# Score : 0.03610482362132128

# %%
mae = mean_absolute_error(y_test, y_pred)

print("MAE :", mae)
# Out:
# MAE : 7.175168850758644

# %%
prediction = model.predict([
    "Poor bus service"
])

print(
    "Predicted Days :",
    prediction[0]
)
# Out:
# Predicted Days : 14.735312558716268

# %%
prediction = model.predict([
    "Hospital cleanliness complaint"
])

print(
    "Predicted Days :",
    prediction[0]
)
# Out:
# Predicted Days : 22.90008476993182

# %%
prediction = model.predict([
    "Water leakage issue"
])

print(
    "Predicted Days :",
    prediction[0]
)
# Out:
# Predicted Days : 16.966312008871217

# %%
joblib.dump(
    model,
    "grievx_svm_regression_model.joblib"
)

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'expanded_historical_complaints_dataset.csv',
#  'grievx_svm_regression_model.joblib',
#  'sample_data']
